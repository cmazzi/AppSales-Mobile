# %% [markdown]
# <a href="https://colab.research.google.com/github/cmazzi/AppSales-Mobile/blob/master/TestRegrLin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/bikeshare.csv'
bikes = pd.read_csv(url)
bikes.head()
# Out:
#               datetime  season  holiday  ...  casual  registered  count
# 0  2011-01-01 00:00:00       1        0  ...       3          13     16
# 1  2011-01-01 01:00:00       1        0  ...       8          32     40
# 2  2011-01-01 02:00:00       1        0  ...       5          27     32
# 3  2011-01-01 03:00:00       1        0  ...       3          10     13
# 4  2011-01-01 04:00:00       1        0  ...       0           1      1
#
# [5 rows x 12 columns]

# %%
bikes.plot(kind='scatter', x='temp', y='count', alpha=0.2)

# %%
import seaborn as sns
sns.lmplot(x='temp', y='count', data=bikes, aspect=1.5, scatter_kws={'alpha':0.2})

# %%
bikes[['count', 'temp']].corr()
# Out:
#           count      temp
# count  1.000000  0.394454
# temp   0.394454  1.000000

# %%
features_cols = ['temp']
X = bikes[features_cols]
y = bikes['count']
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(X,y)
print (linreg.intercept_)
print (linreg.coef_)
y_predict=linreg.predict(X)
print(y_predict)
# Out:
# 6.046212959616611
# [9.17054048]
# [ 96.2843313   88.7644881   88.7644881  ... 133.88354727 133.88354727
#  126.36370408]
